# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
from google.colab import drive
import sys

drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
sys.path.append('/content/drive/My Drive/provably-robust-boosting')

# %%
! python './drive/My Drive/ML Final Project Files/provably-robust-boosting/eval.py' --iter 11 #--n_eval
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step
# Ensemble of 12/52 trees restored: ./drive/My Drive/ML Final Project Files/provably-robust-boosting/models/models_trees_multiclass/2019-08-06 14:59:51 dataset=fmnist weak_learner=tree model=robust_bound n_train=-1 n_trials_coord=784 eps=0.100 max_depth=30 lr=0.05.model.npy
# te=15.34% (1.4862s)
# lrte=15.94% (2.6431s)
# urte=26.72% (2.69535s)
# TE: 15.34% (1.4862s)  LRTE: 15.94% (2.6431s)  URTE: 26.72% (2.69535s)

# %%
! python './drive/My Drive/ML Final Project Files/provably-robust-boosting/eval.py' --iter 51 --n_eval 1
# Out:
# Ensemble of 52/52 trees restored: ./drive/My Drive/ML Final Project Files/provably-robust-boosting/models/models_trees_multiclass/2019-08-06 14:59:51 dataset=fmnist weak_learner=tree model=robust_bound n_train=-1 n_trials_coord=784 eps=0.100 max_depth=30 lr=0.05.model.npy
# ---------------------------------------------------------------------------
# transform_attack_x_test_raw.npy Results:
#
# Worked Correctly
# te=43.14% (3.3549s)
# lrte=43.90% (10.3701s)
# urte=61.21% (15.16411s)
# TE: 43.14% (3.3549s)  LRTE: 43.90% (10.3701s)  URTE: 61.21% (15.16411s)
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# test_mnist_x.npy Results:
#
# te=13.65% (0.2668s)
# lrte=14.00% (0.9444s)
# urte=25.05% (1.70181s)
# TE: 13.65% (0.2668s)  LRTE: 14.00% (0.9444s)  URTE: 25.05% (1.70181s)
# ---------------------------------------------------------------------------
# ...
